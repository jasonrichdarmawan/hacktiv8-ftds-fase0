# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(5, 10)
y = np.arange(12, 17)
display(x, y)
plt.plot(x,y)
# Out:
# array([5, 6, 7, 8, 9])
# array([12, 13, 14, 15, 16])

# %%
vector_A = np.array([1,2])
print("vector_A.shape", vector_A.shape)
matrix_A = np.array([
    [1,2],
    [3,4]
])
print("matrix_A.shape", matrix_A.shape)
tensor_A = np.array([
    [
        [1,2],
        [3,4]
    ],
    [
        [5,6],
        [7,8]
    ]
])
display(tensor_A)
print("tensor_A.shape", tensor_A.shape)
# Out:
# vector_A.shape (2,)
# matrix_A.shape (2, 2)
# array([[[1, 2],
#         [3, 4]],
#
#        [[5, 6],
#         [7, 8]]])
# tensor_A.shape (2, 2, 2)
