# %%
# NGC 9

import random
import matplotlib.pyplot as plt

heads_tails = [0,0]

for i in range(50000):
    result = random.randint(0,1) # heads == 0; tails == 0
    heads_tails[result] += 1

print(heads_tails)

plt.pie(heads_tails, labels=['heads', 'tail'])
# Out:
# [25051, 24949]
