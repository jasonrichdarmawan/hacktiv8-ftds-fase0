# %% [markdown]
# Reference: https://github.com/ardhiraka/FSDS_Guidelines/blob/master/p1/w1/assignments/G1.md

# %% [markdown]
# # 1 - Perkenalan
#
# > Bab pengenalan harus diisi dengan identitas, gambaran besar dataset yang digunakan, dan objective yang ingin dicapai.

# %% [markdown]
# Nama : Jason Rich Darmawan Onggo Putra
#
# Batch : 016 RMT
#
# Dataset: Rating dan atribut pemain FIFA 20222
#
# Objective: Memprediksi rating pemain FIFA 2022

# %% [markdown]
# # 2 - Import Libraries
#
# > Cell pertama pada notebook harus berisi dan hanya berisi semua library yang digunakan dalam project.

# %%
# Import Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OrdinalEncoder

from sklearn.linear_model import LinearRegression

from sklearn.metrics import mean_absolute_error

import joblib
import json

# %% [markdown]
# # 3 - Data Loading
#
# > Bagian ini berisi proses penyiapan data sebelum dilakukan eksplorasi data lebih lanjut. Proses Data Loading dapat berupa memberi nama baru untuk setiap kolom, mengecek ukuran dataset, dll.

# %%
data = pd.read_csv("./P1W1D1PM - Machine Learning Problem Framing.csv")
data
# Out:
#                     Name  Age  Height  Weight   ValueEUR AttackingWorkRate  \
# 0               L. Messi   34     170      72   78000000            Medium
# 1         R. Lewandowski   32     185      81  119500000              High
# 2      Cristiano Ronaldo   36     187      83   45000000              High
# 3              K. Mbappé   22     182      73  194000000              High
# 4               J. Oblak   28     188      87  112000000            Medium
# ...                  ...  ...     ...     ...        ...               ...
# 19255           S. Black   19     180      75     100000            Medium
# 19256            Ma Zhen   23     196      85      50000            Medium
# 19257         Yang Haoyu   20     183      77      90000            Medium
# 19258           He Siwei   20     174      69     100000            Medium
# 19259      Chen Guoliang   22     186      70      70000            Medium
#
#       DefensiveWorkRate  PaceTotal  ShootingTotal  PassingTotal  \
# ...

# %%
# Duplicate Dataset

data_duplicate = data.copy()

# %%
# Rename Columns

data.rename(columns={'ValueEUR': 'price', 'Overall': 'Rating'}, inplace=True)
data
# Out:
#                     Name  Age  Height  Weight      price AttackingWorkRate  \
# 0               L. Messi   34     170      72   78000000            Medium
# 1         R. Lewandowski   32     185      81  119500000              High
# 2      Cristiano Ronaldo   36     187      83   45000000              High
# 3              K. Mbappé   22     182      73  194000000              High
# 4               J. Oblak   28     188      87  112000000            Medium
# ...                  ...  ...     ...     ...        ...               ...
# 19255           S. Black   19     180      75     100000            Medium
# 19256            Ma Zhen   23     196      85      50000            Medium
# 19257         Yang Haoyu   20     183      77      90000            Medium
# 19258           He Siwei   20     174      69     100000            Medium
# 19259      Chen Guoliang   22     186      70      70000            Medium
#
#       DefensiveWorkRate  PaceTotal  ShootingTotal  PassingTotal  \
# ...

# %%
# Check Dataset - 1

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19260 entries, 0 to 19259
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               19260 non-null  object
#  1   Age                19260 non-null  int64
#  2   Height             19260 non-null  int64
#  3   Weight             19260 non-null  int64
#  4   price              19260 non-null  int64
#  5   AttackingWorkRate  19260 non-null  object
#  6   DefensiveWorkRate  19260 non-null  object
#  7   PaceTotal          19260 non-null  int64
#  8   ShootingTotal      19260 non-null  int64
#  9   PassingTotal       19260 non-null  int64
#  10  DribblingTotal     19260 non-null  int64
#  11  DefendingTotal     19260 non-null  int64
#  12  PhysicalityTotal   19260 non-null  int64
#  13  Rating             19260 non-null  int64
# dtypes: int64(11), object(3)
# memory usage: 2.1+ MB

# %% [markdown]
# statement:
# 1. tidak ada column dengan null value.
# 2. dst..

# %%
# Check Dataset - 2

data.describe()
# Out:
#                 Age        Height        Weight         price     PaceTotal  \
# count  19260.000000  19260.000000  19260.000000  1.926000e+04  19260.000000
# mean      25.184683    181.305036     74.950779  2.857652e+06     67.910228
# std        4.737340      6.866151      7.066864  7.604532e+06     10.656453
# min       16.000000    155.000000     49.000000  0.000000e+00     28.000000
# 25%       21.000000    176.000000     70.000000  4.750000e+05     62.000000
# 50%       25.000000    181.000000     75.000000  9.750000e+05     68.000000
# 75%       29.000000    186.000000     80.000000  2.000000e+06     75.000000
# max       54.000000    206.000000    110.000000  1.940000e+08     97.000000
#
#        ShootingTotal  PassingTotal  DribblingTotal  DefendingTotal  \
# count   19260.000000  19260.000000    19260.000000      19260.0000
# mean       53.535514     57.853323       63.028712         50.0581
# std        13.813476      9.835494        9.704853         16.3888
# ...

# %% [markdown]
# statement (kenapa pakai pandas.DataFrame.describe() -> berikan tafsirannya):
# 1. rata-rata orang Asia hanya 175 (berdasarkan citation, dst, cantumkan linknya). Sedangkan, rata-rata di dataset adalah 181. Maka dapat disimpulkan, dataset ini tidak didominasi oleh orang Asia.
# 2. dst..

# %% [markdown]
# # 4 - Exploratory Data Analysis (EDA)
#
# > Bagian ini berisi eksplorasi data pada dataset diatas dengan menggunakan query, grouping, visualisasi sederhana, dan lain sebagainya.

# %% [markdown]
# Alasan histogram : ingin melihat pesebaran rating pada dataset dan juga ingin melihat proporsi antara berat badan dan tinggi badan

# %%
# Create Histogram dan Scatter Plot

plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
sns.histplot(data['Rating'], kde=True, bins=30)
plt.title("Histogram of Rating")

plt.subplot(1, 2, 2)
sns.scatterplot(x='Weight', y='Height', data=data)
plt.title('Weight vs Height')
plt.show()

# %% [markdown]
# statement:
# 1. Mayoritas pemain bola memiliki proporsi yang ideal.

# %% [markdown]
# # 5 - Data Preprocessing
#
# > Bagian ini berisi eksplorasi data pada dataset diatas dengan menggunakan query, grouping, visualisasi sederhana, dan lain sebagainya.

# %% [markdown]
# ## Get Data for Model Inference
#
# ![dataset inference](./images/Screen%20Shot%202022-10-31%20at%2014.18.11.png)
#
# Dataset Inference adalah dataset untuk diuji setelah model ditrain.

# %%
# Get Data for Model Inference

data_inf = data.sample(10, random_state=17)
data_inf
# Out:
#                 Name  Age  Height  Weight    price AttackingWorkRate  \
# 9456    F. Berenguer   32     180      70   675000              High
# 6380          Lasure   27     175      75  1500000            Medium
# 1970        G. Plata   20     178      65  9500000              High
# 8012       D. Azcona   37     184      81   110000            Medium
# 13209  X. Dziekoński   17     188      78  1100000            Medium
# 4544         L. Reis   21     178      78  4200000            Medium
# 12638       A. Rojas   25     170      67   625000              High
# 13055      V. Ábrego   24     176      69   775000            Medium
# 13796       T. Baldé   19     182      68   900000            Medium
# 4641      J. Delgado   28     176      71  1600000            Medium
#
#       DefensiveWorkRate  PaceTotal  ShootingTotal  PassingTotal  \
# 9456                Low         73             63            65
# 6380             Medium         71             44            58
# ...

# %%
# Remove Inference-Set from Dataset

data_train_test = data.drop(data_inf.index)
data_train_test
# Out:
#                     Name  Age  Height  Weight      price AttackingWorkRate  \
# 0               L. Messi   34     170      72   78000000            Medium
# 1         R. Lewandowski   32     185      81  119500000              High
# 2      Cristiano Ronaldo   36     187      83   45000000              High
# 3              K. Mbappé   22     182      73  194000000              High
# 4               J. Oblak   28     188      87  112000000            Medium
# ...                  ...  ...     ...     ...        ...               ...
# 19255           S. Black   19     180      75     100000            Medium
# 19256            Ma Zhen   23     196      85      50000            Medium
# 19257         Yang Haoyu   20     183      77      90000            Medium
# 19258           He Siwei   20     174      69     100000            Medium
# 19259      Chen Guoliang   22     186      70      70000            Medium
#
#       DefensiveWorkRate  PaceTotal  ShootingTotal  PassingTotal  \
# ...

# %%
# Reset Index

data_train_test.reset_index(drop=True, inplace=True)
data_inf.reset_index(drop=True, inplace=True)
data_inf
# Out:
#             Name  Age  Height  Weight    price AttackingWorkRate  \
# 0   F. Berenguer   32     180      70   675000              High
# 1         Lasure   27     175      75  1500000            Medium
# 2       G. Plata   20     178      65  9500000              High
# 3      D. Azcona   37     184      81   110000            Medium
# 4  X. Dziekoński   17     188      78  1100000            Medium
# 5        L. Reis   21     178      78  4200000            Medium
# 6       A. Rojas   25     170      67   625000              High
# 7      V. Ábrego   24     176      69   775000            Medium
# 8       T. Baldé   19     182      68   900000            Medium
# 9     J. Delgado   28     176      71  1600000            Medium
#
#   DefensiveWorkRate  PaceTotal  ShootingTotal  PassingTotal  DribblingTotal  \
# 0               Low         73             63            65              67
# 1            Medium         71             44            58              61
# ...

# %% [markdown]
# ## Splitting between X (Features) and y (Target)

# %%
X = data_train_test.drop(['Rating'], axis="columns")
y = data_train_test['Rating']
X
# Out:
#                     Name  Age  Height  Weight      price AttackingWorkRate  \
# 0               L. Messi   34     170      72   78000000            Medium
# 1         R. Lewandowski   32     185      81  119500000              High
# 2      Cristiano Ronaldo   36     187      83   45000000              High
# 3              K. Mbappé   22     182      73  194000000              High
# 4               J. Oblak   28     188      87  112000000            Medium
# ...                  ...  ...     ...     ...        ...               ...
# 19245           S. Black   19     180      75     100000            Medium
# 19246            Ma Zhen   23     196      85      50000            Medium
# 19247         Yang Haoyu   20     183      77      90000            Medium
# 19248           He Siwei   20     174      69     100000            Medium
# 19249      Chen Guoliang   22     186      70      70000            Medium
#
#       DefensiveWorkRate  PaceTotal  ShootingTotal  PassingTotal  \
# ...

# %%
# Splitting between Train-Set and Test-Set

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=17)

print('Train Size : ', X_train.shape)
print('Test Size : ', X_test.shape)
# Out:
# Train Size :  (15400, 13)
# Test Size :  (3850, 13)

# %% [markdown]
# ## Handling Outlier

# %% [markdown]
# > Ini akan dijelaskan pada pertemuan Selasa, 01 November 2022.

# %% [markdown]
# ## Handling Missing Values

# %% [markdown]
# > Ini akan dijelaskan pada pertemuan Selasa, 01 November 2022

# %%
# Check Missing Values in `X_train`

X_train.isnull().sum()
# Out:
# Name                 0
# Age                  0
# Height               0
# Weight               0
# price                0
# AttackingWorkRate    0
# DefensiveWorkRate    0
# PaceTotal            0
# ShootingTotal        0
# PassingTotal         0
# DribblingTotal       0
# DefendingTotal       0
# PhysicalityTotal     0
# dtype: int64

# %%
# Check Missing Values in `X_test`

X_test.isnull().sum()
# Out:
# Name                 0
# Age                  0
# Height               0
# Weight               0
# price                0
# AttackingWorkRate    0
# DefensiveWorkRate    0
# PaceTotal            0
# ShootingTotal        0
# PassingTotal         0
# DribblingTotal       0
# DefendingTotal       0
# PhysicalityTotal     0
# dtype: int64

# %%
# Example of column with nan values

pd.Series([1, np.nan]).isnull().sum()
# Out:
# 1

# %%
# Check Missing Values in `y_train`

y_train.isnull().sum()
# Out:
# 0

# %%
# Check Missing Values in `y_test`

y_test.isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Feature Selection

# %%
# Display X_train

X_train
# Out:
#                    Name  Age  Height  Weight     price AttackingWorkRate  \
# 9235           Quintana   19     186      74   1900000            Medium
# 4199           R. Manaj   24     182      76   3800000            Medium
# 12940        E. Vergani   20     186      77   1100000              High
# 8147       Talles Magno   19     186      70   2600000              High
# 15074     Lee Bum Young   32     197      93    160000            Medium
# ...                 ...  ...     ...     ...       ...               ...
# 9529   Ricardo Ferreira   28     190      82         0               Low
# 406             Everton   25     174      72  28000000              High
# 13702      Bruno Jordão   22     180      73    900000            Medium
# 2191        Lino Essier   29     183      77   3500000            Medium
# 10863      F. Eboa Eboa   24     186      80    925000               Low
#
#       DefensiveWorkRate  PaceTotal  ShootingTotal  PassingTotal  \
# ...

# %% [markdown]
# Berdasarkan Personal Judgement, tidak ada kaitannya antara column `Name` dengan column `Rating`. Hal ini dibuktikan dengan nama `Danu Ronaldo` tidak ada kaitannya dengan nama sepopuler `Cristiano Ronaldo`

# %%
X_train.drop('Name', axis='columns', inplace=True)
X_test.drop('Name', axis='columns', inplace=True)
X_train
# Out:
#        Age  Height  Weight     price AttackingWorkRate DefensiveWorkRate  \
# 9235    19     186      74   1900000            Medium              High
# 4199    24     182      76   3800000            Medium            Medium
# 12940   20     186      77   1100000              High            Medium
# 8147    19     186      70   2600000              High            Medium
# 15074   32     197      93    160000            Medium            Medium
# ...    ...     ...     ...       ...               ...               ...
# 9529    28     190      82         0               Low            Medium
# 406     25     174      72  28000000              High               Low
# 13702   22     180      73    900000            Medium            Medium
# 2191    29     183      77   3500000            Medium            Medium
# 10863   24     186      80    925000               Low            Medium
#
#        PaceTotal  ShootingTotal  PassingTotal  DribblingTotal  DefendingTotal  \
# ...

# %% [markdown]
# ## Split between Numerical Columns and Categorical Columns

# %% [markdown]
# ![flow](./images/screenshot-14-42.png)
#
# Dataset non-inference train dipecah menjadi:
# 1. numerical data   -> scaling
# 2. categorical data -> encoding ("Adventure" -> "0" atau "1")
#
# Kemudian di-merge -> setelah itu di-train.
#
# ^ Flow ini gak paten. Ada juga:
# 1. pisah numerical dan categorical
# 2. categorical diencoding
# 3. di-merge
# 4. di-scaling

# %%
# Get Numerical columns and Categorical Columns

num_columns = X_train.select_dtypes(include=np.number).columns.tolist()
cat_columns = X_train.select_dtypes(include=['object']).columns.tolist()

print('Numerical Columns :', num_columns)
print('Categorical Columns :', cat_columns)
# Out:
# Numerical Columns : ['Age', 'Height', 'Weight', 'price', 'PaceTotal', 'ShootingTotal', 'PassingTotal', 'DribblingTotal', 'DefendingTotal', 'PhysicalityTotal']
# Categorical Columns : ['AttackingWorkRate', 'DefensiveWorkRate']

# %% [markdown]
# ## Split Train-Set and Test-Set based on Column Types

# %%
X_train_num = X_train[num_columns]
X_test_num = X_test[num_columns]

X_train_cat = X_train[cat_columns]
X_test_cat = X_test[cat_columns]

X_train_num
# Out:
#        Age  Height  Weight     price  PaceTotal  ShootingTotal  PassingTotal  \
# 9235    19     186      74   1900000         63             50            61
# 4199    24     182      76   3800000         69             72            54
# 12940   20     186      77   1100000         63             69            51
# 8147    19     186      70   2600000         85             52            55
# 15074   32     197      93    160000         61             60            59
# ...    ...     ...     ...       ...        ...            ...           ...
# 9529    28     190      82         0         49             32            45
# 406     25     174      72  28000000         86             75            73
# 13702   22     180      73    900000         64             55            60
# 2191    29     183      77   3500000         67             45            68
# 10863   24     186      80    925000         48             44            52
#
# ...

# %% [markdown]
# ## Feature Scaling
#
# ### PENTING
#
# column `Age` rangenya misal 1-50, column `Height` rangenya misalnya 150-200, tiba-tiba ada column `Price` dengan range 1 jt - 100 jt. Dampaknya adalah hasil Model yang telah di-train akan lebih terpengaruh dengan column `Price` ketika Model yang telah di-train diuji.

# %%
X_train_num.describe()
# Out:
#                 Age        Height        Weight         price     PaceTotal  \
# count  15400.000000  15400.000000  15400.000000  1.540000e+04  15400.000000
# mean      25.182273    181.288052     74.926104  2.866596e+06     67.882208
# std        4.729238      6.869126      7.065049  7.538808e+06     10.701932
# min       16.000000    155.000000     49.000000  0.000000e+00     28.000000
# 25%       21.000000    176.000000     70.000000  4.750000e+05     62.000000
# 50%       25.000000    181.000000     75.000000  9.750000e+05     68.000000
# 75%       29.000000    186.000000     80.000000  2.100000e+06     75.000000
# max       54.000000    206.000000    107.000000  1.940000e+08     97.000000
#
#        ShootingTotal  PassingTotal  DribblingTotal  DefendingTotal  \
# count   15400.000000  15400.000000    15400.000000    15400.000000
# mean       53.550195     57.848117       63.017338       50.084351
# std        13.835679      9.807584        9.722490       16.375305
# ...

# %% [markdown]
# sklearn.preprocessing.MinMaxScaler mengubah data column menjadi range 0-1.
#
# ![MinMaxScaler](./images/Screen%20Shot%202022-10-31%20at%2014.53.32.png)
# ![MinMaxScaler in action](./images/Screen%20Shot%202022-10-31%20at%2015.01.24.png)
#
# ### PENTING
#
# MinMaxScaler.fit(X_train_num) -> hanya untuk Data Non-Inference Train Numerical

# %%
# Feature Scaling using MinMaxScaler

scaler = MinMaxScaler()
scaler.fit(X_train_num)

X_train_num_scaled = scaler.transform(X_train_num)
X_test_num_scaled = scaler.transform(X_test_num)
X_train_num_scaled
# Out:
# array([[0.07894737, 0.60784314, 0.43103448, ..., 0.53030303, 0.66233766,
#         0.55555556],
#        [0.21052632, 0.52941176, 0.46551724, ..., 0.66666667, 0.18181818,
#         0.63492063],
#        [0.10526316, 0.60784314, 0.48275862, ..., 0.62121212, 0.09090909,
#         0.3968254 ],
#        ...,
#        [0.15789474, 0.49019608, 0.4137931 , ..., 0.63636364, 0.45454545,
#         0.49206349],
#        [0.34210526, 0.54901961, 0.48275862, ..., 0.60606061, 0.76623377,
#         0.79365079],
#        [0.21052632, 0.60784314, 0.53448276, ..., 0.40909091, 0.64935065,
#         0.73015873]])

# %%
import seaborn as sns
sns.kdeplot(pd.DataFrame(X_train_num_scaled, columns=X_train_num.columns))
# Out:
# <AxesSubplot: ylabel='Density'>

# %% [markdown]
# ## Feature Encoding
#
# One Hot Encoding -> "Action" jadi 0 atau 1.
#
# Ordinal -> "Low" jadi 0, "Medium" jadi 1, dst.

# %%
# Display X_train_cat

X_train_cat
# Out:
#       AttackingWorkRate DefensiveWorkRate
# 9235             Medium              High
# 4199             Medium            Medium
# 12940              High            Medium
# 8147               High            Medium
# 15074            Medium            Medium
# ...                 ...               ...
# 9529                Low            Medium
# 406                High               Low
# 13702            Medium            Medium
# 2191             Medium            Medium
# 10863               Low            Medium
#
# [15400 rows x 2 columns]

# %% [markdown]
# ### PENTING
#
# sklearn.preprocessing.OrdinalEncoder.fit(X_train_cat) hanya untuk Dataset Non-Inferencial Train Categorical Data.

# %%
# Feature Encoding using OrdinalEncoder

encoder = OrdinalEncoder(categories=[["Low", "Medium", "High"],
                                     ["Low", "Medium", "High"]])
encoder.fit(X_train_cat)

X_train_cat_encoded = encoder.transform(X_train_cat)
X_test_cat_encoded = encoder.transform(X_test_cat)
X_train_cat_encoded
# Out:
# array([[1., 2.],
#        [1., 1.],
#        [2., 1.],
#        ...,
#        [1., 1.],
#        [1., 1.],
#        [0., 1.]])

# %% [markdown]
# ## Concate between Numerical Columns and Categorical Columns

# %% [markdown]
# ### PENTING
#
# pastikan `len(scaled)`, `len(encoded)` sama ya.

# %%
print(len(X_train_num_scaled), len(X_train_cat_encoded))
print(len(X_test_num_scaled), len(X_test_cat_encoded))
# Out:
# 15400 15400
# 3850 3850

# %%
# Concate Columns

X_train_final = np.concatenate([X_train_num_scaled, X_train_cat_encoded], axis=1)
X_test_final = np.concatenate([X_test_num_scaled, X_test_cat_encoded], axis=1)

# %%
# Create DataFrame of `X_train_final`

X_train_final_df = pd.DataFrame(X_train_final, columns=[num_columns + cat_columns])
X_train_final_df
# Out:
#             Age    Height    Weight     price PaceTotal ShootingTotal  \
# 0      0.078947  0.607843  0.431034  0.009794  0.507246      0.421053
# 1      0.210526  0.529412  0.465517  0.019588  0.594203      0.710526
# 2      0.105263  0.607843  0.482759  0.005670  0.507246      0.671053
# 3      0.078947  0.607843  0.362069  0.013402  0.826087      0.447368
# 4      0.421053  0.823529  0.758621  0.000825  0.478261      0.552632
# ...         ...       ...       ...       ...       ...           ...
# 15395  0.315789  0.686275  0.568966  0.000000  0.304348      0.184211
# 15396  0.236842  0.372549  0.396552  0.144330  0.840580      0.750000
# 15397  0.157895  0.490196  0.413793  0.004639  0.521739      0.486842
# 15398  0.342105  0.549020  0.482759  0.018041  0.565217      0.355263
# 15399  0.210526  0.607843  0.534483  0.004768  0.289855      0.342105
#
#       PassingTotal DribblingTotal DefendingTotal PhysicalityTotal  \
# ...

# %% [markdown]
# # 6 - Model Definition
#
# > Bagian ini berisi cell untuk mendefinisikan model. Jelaskan alasan menggunakan suatu algoritma/model, hyperparameter yang dipakai, jenis penggunaan metrics yang dipakai, dan hal lain yang terkait dengan model.

# %% [markdown]
# Notes :
#
# 1. Algoritma yang akan dipakai adalah `Linear Regression`.
#    * Alasan menggunakan Linear Regression adalah ...
#
# 2. Metrics yang akan dipakai adalah `Mean Absolute Error (MAE)`
#    * Alasan menggunakan MAE adalah ...

# %%
# Training using Linear Regression

model_lin_reg = LinearRegression()

# %% [markdown]
# # 7 - Model Training
#
# > Cell pada bagian ini hanya berisi code untuk melatih model dan output yang dihasilkan. Lakukan beberapa kali proses training dengan hyperparameter yang berbeda untuk melihat hasil yang didapatkan. Analisis dan narasikan hasil ini pada bagian Model Evaluation.
#
# hyperparameter itu args.
#
# `model_lin_reg = LinearRegression( args )`

# %%
# Train the Model

model_lin_reg.fit(X_train_final, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # 8 - Model Evaluation
#
# > Pada bagian ini, dilakukan evaluasi model yang harus menunjukkan bagaimana performa model berdasarkan metrics yang dipilih. Hal ini harus dibuktikan dengan visualisasi tren performa dan/atau tingkat kesalahan model. Lakukan analisis terkait dengan hasil pada model dan tuliskan hasil analisisnya.

# %%
# Predict Train-Set and Test-Set

y_pred_train = model_lin_reg.predict(X_train_final)
y_pred_test = model_lin_reg.predict(X_test_final)

y_pred_train
# Out:
# array([64.77235831, 67.26408179, 60.64755635, ..., 65.28434857,
#        73.09864515, 64.89410413])

# %%
# Display `y_train`

# y_pred_train[0] = 64.77235831 sedangkan y_train[0] = 66
# berarti prediksinya salah.

y_train
# Out:
# 9235     66
# 4199     71
# 12940    63
# 8147     67
# 15074    61
#          ..
# 9529     66
# 406      80
# 13702    62
# 2191     74
# 10863    65
# Name: Rating, Length: 15400, dtype: int64

# %%
# Model Evaluation using MAE

print('Error - Train Set :', mean_absolute_error(y_train, y_pred_train))
print('Error - Test Set :', mean_absolute_error(y_test, y_pred_test))
# Out:
# Error - Train Set : 2.351340115442289
# Error - Test Set : 2.3497331721374164

# %%
print(y_train.iloc[0] / (y_pred_train[0] + mean_absolute_error(y_train, y_pred_train)))
print(y_test.iloc[0] / (y_pred_test[0] + mean_absolute_error(y_test, y_pred_test)))
# Out:
# 0.9832592891252829
# 0.9215153457707321

# %% [markdown]
# Statement:
#
# 1. Nyatakan apakah model tergolong
#    * overfit (modelnya bagus ketika train tapi jelek ketika test / gap performa antara train dan test besar)
#    * underfit (modelnya kurang train -> performa model ketika train dan test dibawah 70%)
#    * good-fit (modelnya acceptable / gap perfoma antara train dan test kecil, dan perfoma nya mendekati 100%)
# 2. Narasikan dalam hal bisnis.
# 3. Tentukan hal yang unik.

# %%
# 9 - Model Saving

# wb = write binary

with open('model/model_lin_reg.pkl', 'wb') as file_1:
    joblib.dump(model_lin_reg, file_1)

with open('model/model_scaler.pkl', 'wb') as file_2:
    joblib.dump(scaler, file_2)

with open('model/model_encoder.pkl', 'wb') as file_3:
    joblib.dump(encoder, file_3)

with open('model/list_num_cols.txt', 'w') as file_4:
    json.dump(num_columns, file_4)

with open('model/list_cat_cols.txt', 'w') as file_5:
    json.dump(cat_columns, file_5)

# %% [markdown]
# # 10 - Model Inference
#
# > Model yang sudah dilatih akan dicoba pada data yang bukan termasuk ke dalam train-set ataupun test-set. Data ini harus dalam format yang asli, bukan data yang sudah di-scaled.

# %% [markdown]
# ## Load Model

# %%
# Load All Files

import joblib
import json

with open('model/model_lin_reg.pkl', 'rb') as file_1:
    model_lin_reg = joblib.load(file_1)

with open('model/model_scaler.pkl', 'rb') as file_2:
    model_scaler = joblib.load(file_2)

with open('model/model_encoder.pkl', 'rb') as file_3:
    model_encoder = joblib.load(file_3)

with open('model/list_num_cols.txt', 'r') as file_4:
    list_num_cols = json.load(file_4)

with open('model/list_cat_cols.txt', 'r') as file_5:
    list_cat_cols = json.load(file_5)

# %% [markdown]
# ## Inference

# %%
# Display Inference Set

data_inf
# Out:
#             Name  Age  Height  Weight    price AttackingWorkRate  \
# 0   F. Berenguer   32     180      70   675000              High
# 1         Lasure   27     175      75  1500000            Medium
# 2       G. Plata   20     178      65  9500000              High
# 3      D. Azcona   37     184      81   110000            Medium
# 4  X. Dziekoński   17     188      78  1100000            Medium
# 5        L. Reis   21     178      78  4200000            Medium
# 6       A. Rojas   25     170      67   625000              High
# 7      V. Ábrego   24     176      69   775000            Medium
# 8       T. Baldé   19     182      68   900000            Medium
# 9     J. Delgado   28     176      71  1600000            Medium
#
#   DefensiveWorkRate  PaceTotal  ShootingTotal  PassingTotal  DribblingTotal  \
# 0               Low         73             63            65              67
# 1            Medium         71             44            58              61
# ...

# %%
# Split between Numerical Columns and Categorical Columns

data_inf_num = data_inf[list_num_cols]
data_inf_cat = data_inf[list_cat_cols]

data_inf_num
# Out:
#    Age  Height  Weight    price  PaceTotal  ShootingTotal  PassingTotal  \
# 0   32     180      70   675000         73             63            65
# 1   27     175      75  1500000         71             44            58
# 2   20     178      65  9500000         85             66            65
# 3   37     184      81   110000         67             63            67
# 4   17     188      78  1100000         62             64            62
# 5   21     178      78  4200000         75             57            67
# 6   25     170      67   625000         73             61            55
# 7   24     176      69   775000         62             64            49
# 8   19     182      68   900000         70             36            51
# 9   28     176      71  1600000         76             63            63
#
#    DribblingTotal  DefendingTotal  PhysicalityTotal
# 0              67              48                68
# 1              61              64                76
# ...

# %%
# Feature Scaling and Feature Encoding

data_inf_num_scaled = model_scaler.transform(data_inf_num)
data_inf_cat_encoded = model_encoder.transform(data_inf_cat)

data_inf_num_scaled
# Out:
# array([[4.21052632e-01, 4.90196078e-01, 3.62068966e-01, 3.47938144e-03,
#         6.52173913e-01, 5.92105263e-01, 5.88235294e-01, 6.21212121e-01,
#         4.41558442e-01, 6.19047619e-01],
#        [2.89473684e-01, 3.92156863e-01, 4.48275862e-01, 7.73195876e-03,
#         6.23188406e-01, 3.42105263e-01, 4.85294118e-01, 5.30303030e-01,
#         6.49350649e-01, 7.46031746e-01],
#        [1.05263158e-01, 4.50980392e-01, 2.75862069e-01, 4.89690722e-02,
#         8.26086957e-01, 6.31578947e-01, 5.88235294e-01, 8.03030303e-01,
#         3.76623377e-01, 5.55555556e-01],
#        [5.52631579e-01, 5.68627451e-01, 5.51724138e-01, 5.67010309e-04,
#         5.65217391e-01, 5.92105263e-01, 6.17647059e-01, 6.36363636e-01,
#         4.28571429e-01, 6.34920635e-01],
#        [2.63157895e-02, 6.47058824e-01, 5.00000000e-01, 5.67010309e-03,
#         4.92753623e-01, 6.05263158e-01, 5.44117647e-01, 5.60606061e-01,
#         2.46753247e-01, 5.71428571e-01],
# ...

# %%
# Example of axis=0
np.concatenate([[1,2],[3,4]], axis=0)
# Out:
# array([1, 2, 3, 4])

# %%
# Example of axis=1
np.concatenate([[['1row1col1'],['2row2col1']],[['3row1col2'],['4row2col2']]], axis=1)
# Out:
# array([['1row1col1', '3row1col2'],
#        ['2row2col1', '4row2col2']], dtype='<U9')

# %%
# Concate Numerical Columns and Categorical Columns

data_inf_final = np.concatenate([data_inf_num_scaled, data_inf_cat_encoded], axis=1)
data_inf_final
# Out:
# array([[4.21052632e-01, 4.90196078e-01, 3.62068966e-01, 3.47938144e-03,
#         6.52173913e-01, 5.92105263e-01, 5.88235294e-01, 6.21212121e-01,
#         4.41558442e-01, 6.19047619e-01, 2.00000000e+00, 0.00000000e+00],
#        [2.89473684e-01, 3.92156863e-01, 4.48275862e-01, 7.73195876e-03,
#         6.23188406e-01, 3.42105263e-01, 4.85294118e-01, 5.30303030e-01,
#         6.49350649e-01, 7.46031746e-01, 1.00000000e+00, 1.00000000e+00],
#        [1.05263158e-01, 4.50980392e-01, 2.75862069e-01, 4.89690722e-02,
#         8.26086957e-01, 6.31578947e-01, 5.88235294e-01, 8.03030303e-01,
#         3.76623377e-01, 5.55555556e-01, 2.00000000e+00, 0.00000000e+00],
#        [5.52631579e-01, 5.68627451e-01, 5.51724138e-01, 5.67010309e-04,
#         5.65217391e-01, 5.92105263e-01, 6.17647059e-01, 6.36363636e-01,
#         4.28571429e-01, 6.34920635e-01, 1.00000000e+00, 1.00000000e+00],
#        [2.63157895e-02, 6.47058824e-01, 5.00000000e-01, 5.67010309e-03,
# ...

# %%
# Predict using Linear Regression

y_pred_inf = model_lin_reg.predict(data_inf_final)
y_pred_inf
# Out:
# array([69.40855954, 68.65888225, 71.67029745, 70.67068251, 62.80545363,
#        71.70469958, 61.41859391, 63.16158652, 61.90926356, 68.86685688])

# %%
# Create DataFrame

y_pred_inf_df = pd.DataFrame(y_pred_inf, columns=['Rating - Prediction'])
y_pred_inf_df
# Out:
#    Rating - Prediction
# 0            69.408560
# 1            68.658882
# 2            71.670297
# 3            70.670683
# 4            62.805454
# 5            71.704700
# 6            61.418594
# 7            63.161587
# 8            61.909264
# 9            68.866857

# %%
# Concate between Inference-Set and Rating's Prediction

pd.concat([data_inf, y_pred_inf_df], axis=1)
# Out:
#             Name  Age  Height  Weight    price AttackingWorkRate  \
# 0   F. Berenguer   32     180      70   675000              High
# 1         Lasure   27     175      75  1500000            Medium
# 2       G. Plata   20     178      65  9500000              High
# 3      D. Azcona   37     184      81   110000            Medium
# 4  X. Dziekoński   17     188      78  1100000            Medium
# 5        L. Reis   21     178      78  4200000            Medium
# 6       A. Rojas   25     170      67   625000              High
# 7      V. Ábrego   24     176      69   775000            Medium
# 8       T. Baldé   19     182      68   900000            Medium
# 9     J. Delgado   28     176      71  1600000            Medium
#
#   DefensiveWorkRate  PaceTotal  ShootingTotal  PassingTotal  DribblingTotal  \
# 0               Low         73             63            65              67
# 1            Medium         71             44            58              61
# ...

# %% [markdown]
# # 11 - Kesimpulan
#
# > Pada bagian terakhir ini, harus berisi kesimpulan yang mencerminkan hasil yang didapat dengan objective yang sudah ditulis di bagian pengenalan.

# %% [markdown]
# 1. Narasi based on EDA.
# 2. Narasi based on Model Analysis.
# 3. Narasi based on Model Evaluation.
# 4. Further Improvement.
# 5. Hal lain seperti Kelemahan, Keklebihan Model.

# %%
# Get Intercept and Slope

# Rules -> Rating pemain = 36.2 + 7.5 * Age + 2.06 * Height + ... + -0.5 * DefensiveWorkRate

print('Intercept    :', model_lin_reg.intercept_)
print('Slope        :', model_lin_reg.coef_)
# Out:
# Intercept    : 36.22253237163134
# Slope        : [ 7.5883957   2.06442948  1.05385459 39.15907544  3.15439873  2.99799434
#   2.19712841 20.37879803  8.21691507 12.44338743 -0.32725332 -0.50123917]

# %%
# List All Columns

X_train_final_df.columns
# Out:
# MultiIndex([(              'Age',),
#             (           'Height',),
#             (           'Weight',),
#             (            'price',),
#             (        'PaceTotal',),
#             (    'ShootingTotal',),
#             (     'PassingTotal',),
#             (   'DribblingTotal',),
#             (   'DefendingTotal',),
#             ( 'PhysicalityTotal',),
#             ('AttackingWorkRate',),
#             ('DefensiveWorkRate',)],
#            )
