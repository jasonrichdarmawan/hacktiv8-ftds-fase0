# %% [markdown]
# # NOT DONE
#
# GridSearchCV + KerasClassifier tidak bagus.
# 1. GridSearchCV melakukan split data set menjadi train set + validation set.
#
#    Fungsinya adalah untuk mendapatkan average score dan average score tertinggi akan dianggap sebagai `GridSearchCV.best_score_` dan `GridSearchCV.best_params_`.
# 2. Ini berarti jika `GridSearchCV(cv=3)` maka KerasClassifier hanya mendapatkan 2/3 train set. Sedangkan 1/3 train set digunakan oleh GridSearchCV sebagai validaiton set.
# 3. Hal ini diperparah oleh cara kerja `tf.keras.models.Sequential` yang membutuhkan validation set agar tidak overfit.

# %% [markdown]
# # Import Libraries

# %%
# Data Loading
import pandas as pd

# Data Preprocessing
from sklearn.model_selection import train_test_split
from pandas.api.types import CategoricalDtype

# Pipeline
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
import numpy as np

# GridSearchCV
from sklearn.metrics import make_scorer, f1_score, classification_report
from scikeras.wrappers import KerasClassifier
from sklearn.model_selection import GridSearchCV
import tensorflow_addons as tfa
from sklearn.feature_selection import mutual_info_classif, SelectKBest

# reference: https://stackoverflow.com/questions/35911252/disable-tensorflow-debugging-information
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import tensorflow as tf

# %% [markdown]
# # Data Loading

# %%
df = pd.read_csv('./WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
# Convert TotalCharges type from string to number
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')
df['TotalCharges'].fillna(0, inplace=True)

# %% [markdown]
# # Data Preprocessing

# %%
# Split data set
X = df.drop('Churn', axis=1)
y = df['Churn']
X_train_val, X_test, y_train_val, y_test = train_test_split(
    X, y, test_size=0.15, stratify=y, random_state=0)
X_train, X_val, y_train, y_val= train_test_split(
    X_train_val, y_train_val, test_size=0.15, stratify=y_train_val, random_state=0)

# %%
# Define data type
nom_cols = ['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService', 
            'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 
            'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 
            'PaperlessBilling', 'PaymentMethod']
ord_cols = ['Contract']
num_cols = ['tenure', 'MonthlyCharges', 'TotalCharges']

# %%
# Change dtypes for OrdinalEncoder or OneHotEncoder
X_train_val['Contract'] = X_train_val['Contract'].astype(
    CategoricalDtype(
        categories=['Month-to-month', 'One year', 'Two year'], ordered=True)
)

X_train_val[nom_cols] = X_train_val[nom_cols].astype('category')

# %% [markdown]
# # Pipeline
#
# [reference](https://stackoverflow.com/questions/58815016/cross-validating-with-imblearn-pipeline-and-gridsearchcv)

# %%
num_pipe = Pipeline(
    steps=[
        ('imputer', SimpleImputer(strategy='median')),
        ('scaler', StandardScaler())
    ]
)

nom_cats = [
    X_train_val['gender'].cat.categories.tolist(),
    X_train_val['SeniorCitizen'].cat.categories.tolist(),
    X_train_val['Partner'].cat.categories.tolist(),
    X_train_val['Dependents'].cat.categories.tolist(),
    X_train_val['PhoneService'].cat.categories.tolist(),
    X_train_val['MultipleLines'].cat.categories.tolist(),
    X_train_val['InternetService'].cat.categories.tolist(),
    X_train_val['OnlineSecurity'].cat.categories.tolist(),
    X_train_val['OnlineBackup'].cat.categories.tolist(),
    X_train_val['DeviceProtection'].cat.categories.tolist(),
    X_train_val['TechSupport'].cat.categories.tolist(),
    X_train_val['StreamingTV'].cat.categories.tolist(),
    X_train_val['StreamingMovies'].cat.categories.tolist(),
    X_train_val['PaperlessBilling'].cat.categories.tolist(),
    X_train_val['PaymentMethod'].cat.categories.tolist()
]

nom_pipe = Pipeline(
    steps=[
        ('imputer', SimpleImputer(strategy='most_frequent')),
        ('encoder', OneHotEncoder(categories=nom_cats)),
    ]
)

ord_pipe = Pipeline(
    steps=[
        ('imputer', SimpleImputer(strategy='most_frequent')),
        ('encoder', OrdinalEncoder(
            categories=[
                X_train_val['Contract'].cat.categories.tolist()
            ]
        )),
    ]
)

composer = ColumnTransformer(
    transformers=[
        ('num_pipe', num_pipe, num_cols),
        ('nom_pipe', nom_pipe, nom_cols),
        ('ord_pipe', ord_pipe, ord_cols)
    ]
)

# %%
# Get discrete features bool
composer.fit(X=X_train_val, y=y_train_val)
print([feature.startswith(("nom", "ord")) for feature in composer.get_feature_names_out()])
# Out:
# [False, False, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]

# %%
def isolate():
    X_train_val_final = composer.transform(X=X_train_val)
    
    mi = mutual_info_classif(
            X=X_train_val_final, y=y_train_val,
            discrete_features=[False, False, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True],
            random_state=0
    )
    
    df_c = pd.DataFrame()
    df_c["mi"] = mi / np.max(mi)
    
    df_c["feature"] = composer.get_feature_names_out()
    display(df_c.sort_values(by="mi", ascending=False)
                .reset_index()
                .style.background_gradient(cmap="coolwarm"))

isolate()
# Out:
# <style type="text/css">
# #T_9a115_row0_col0, #T_9a115_row0_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_9a115_row1_col0, #T_9a115_row38_col1, #T_9a115_row39_col1, #T_9a115_row40_col1, #T_9a115_row41_col1, #T_9a115_row42_col1, #T_9a115_row43_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_9a115_row1_col1 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_9a115_row2_col0 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_9a115_row2_col1, #T_9a115_row34_col0 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_9a115_row3_col0 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_9a115_row3_col1, #T_9a115_row9_col0 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_9a115_row4_col0, #T_9a115_row32_col1 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_9a115_row4_col1 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_9a115_row5_col0 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_9a115_row5_col1 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_9a115_row6_col0 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_9a115_row6_col1 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_9a115_row7_col0, #T_9a115_row35_col1, #T_9a115_row36_col1 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_9a115_row7_col1 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_9a115_row8_col0 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_9a115_row8_col1 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_9a115_row9_col1 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_9a115_row10_col0 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_9a115_row10_col1, #T_9a115_row11_col1, #T_9a115_row12_col1, #T_9a115_row13_col1, #T_9a115_row14_col1, #T_9a115_row15_col1, #T_9a115_row16_col1 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_9a115_row11_col0 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_9a115_row12_col0 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_9a115_row13_col0 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_9a115_row14_col0 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_9a115_row15_col0 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_9a115_row16_col0 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_9a115_row17_col0 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_9a115_row17_col1, #T_9a115_row18_col1 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_9a115_row18_col0 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_9a115_row19_col0 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_9a115_row19_col1, #T_9a115_row24_col0 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_9a115_row20_col0 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_9a115_row20_col1, #T_9a115_row21_col1 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_9a115_row21_col0 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_9a115_row22_col0 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_9a115_row22_col1 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_9a115_row23_col0 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_9a115_row23_col1, #T_9a115_row24_col1, #T_9a115_row26_col0 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_9a115_row25_col0 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_9a115_row25_col1, #T_9a115_row26_col1 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_9a115_row27_col0 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_9a115_row27_col1, #T_9a115_row39_col0 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_9a115_row28_col0 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_9a115_row28_col1 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_9a115_row29_col0 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_9a115_row29_col1 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_9a115_row30_col0 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_9a115_row30_col1 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_9a115_row31_col0 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_9a115_row31_col1 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_9a115_row32_col0 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_9a115_row33_col0 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_9a115_row33_col1 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_9a115_row34_col1 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_9a115_row35_col0 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_9a115_row36_col0 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_9a115_row37_col0 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_9a115_row37_col1 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_9a115_row38_col0 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_9a115_row40_col0 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_9a115_row41_col0 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_9a115_row42_col0 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_9a115_row43_col0 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# </style>
# <table id="T_9a115">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9a115_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_9a115_level0_col1" class="col_heading level0 col1" >mi</th>
#       <th id="T_9a115_level0_col2" class="col_heading level0 col2" >feature</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a115_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9a115_row0_col0" class="data row0 col0" >43</td>
#       <td id="T_9a115_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_9a115_row0_col2" class="data row0 col2" >ord_pipe__Contract</td>
#     </tr>
#     <tr>
#       <th id="T_9a115_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9a115_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_9a115_row1_col1" class="data row1 col1" >0.676495</td>
#       <td id="T_9a115_row1_col2" class="data row1 col2" >num_pipe__tenure</td>
#     </tr>
#     <tr>
#       <th id="T_9a115_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9a115_row2_col0" class="data row2 col0" >19</td>
#       <td id="T_9a115_row2_col1" class="data row2 col1" >0.627687</td>
#       <td id="T_9a115_row2_col2" class="data row2 col2" >nom_pipe__OnlineSecurity_No</td>
#     </tr>
#     <tr>
#       <th id="T_9a115_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9a115_row3_col0" class="data row3 col0" >28</td>
#       <td id="T_9a115_row3_col1" class="data row3 col1" >0.581319</td>
#       <td id="T_9a115_row3_col2" class="data row3 col2" >nom_pipe__TechSupport_No</td>
#     </tr>
#     <tr>
#       <th id="T_9a115_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9a115_row4_col0" class="data row4 col0" >2</td>
#       <td id="T_9a115_row4_col1" class="data row4 col1" >0.503695</td>
#       <td id="T_9a115_row4_col2" class="data row4 col2" >num_pipe__TotalCharges</td>
#     </tr>
#     <tr>
#       <th id="T_9a115_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9a115_row5_col0" class="data row5 col0" >17</td>
#       <td id="T_9a115_row5_col1" class="data row5 col1" >0.472594</td>
#       <td id="T_9a115_row5_col2" class="data row5 col2" >nom_pipe__InternetService_Fiber optic</td>
#     </tr>
#     <tr>
#       <th id="T_9a115_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9a115_row6_col0" class="data row6 col0" >41</td>
#       <td id="T_9a115_row6_col1" class="data row6 col1" >0.441467</td>
#       <td id="T_9a115_row6_col2" class="data row6 col2" >nom_pipe__PaymentMethod_Electronic check</td>
#     </tr>
#     <tr>
#       <th id="T_9a115_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9a115_row7_col0" class="data row7 col0" >1</td>
#       <td id="T_9a115_row7_col1" class="data row7 col1" >0.403700</td>
#       <td id="T_9a115_row7_col2" class="data row7 col2" >num_pipe__MonthlyCharges</td>
#     </tr>
#     <tr>
#       <th id="T_9a115_level0_row8" class="row_heading level0 row8" >8</th>

# %% [markdown]
# # SciKeras KerasClassifier
#
# [reference](https://www.adriangb.com/scikeras/stable/quickstart.html#in-an-sklearn-pipeline)
#
# [reference 2](https://stackoverflow.com/questions/59225328/how-to-use-kerasclassifier-validation-split-and-using-scitkit-learn-gridsearchcv)

# %%
def get_model(hidden_layer_dim, meta):
    n_features_in_ = meta["n_features_in_"]
    X_shape_ = meta["X_shape_"]
    n_classes_ = meta["n_classes_"]
    
    model = tf.keras.models.Sequential()
    model.add(
        tf.keras.layers.Dense(
            units=4, input_shape=X_shape_[1:],
            kernel_initializer=tf.keras.initializers.HeNormal(seed=0)
        )
    )
    model.add(
        tf.keras.layers.BatchNormalization()
    )
    model.add(
        tf.keras.layers.LeakyReLU(alpha=0.3)
    )
    model.add(
        tf.keras.layers.Dense(units=1, activation="sigmoid")
    )
    
    return model

callback = tf.keras.callbacks.EarlyStopping(
    monitor="val_f1_score",
    mode="max",
    patience=10,
    min_delta=0.0001,
    restore_best_weights=True
)

clf = KerasClassifier(
    model=get_model,
    loss="binary_crossentropy",
    hidden_layer_dim=100,
    metrics=tfa.metrics.F1Score,
    metrics__num_classes=1,
    metrics__average='macro',
    metrics__threshold=0.3,
    epochs=100,
    callbacks=[callback],
    validation_split=0.1,
    verbose=False
)

def sel_score(X, y):
    return mutual_info_classif(
        X=X, y=y,
        discrete_features=[False, False, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True],
        random_state=0
    )

pipe = Pipeline(
    steps=[
        ('composer', composer),
        ('sel', SelectKBest(
            score_func=sel_score,
            k=17,  
        )),
        ('clf', clf)
    ]
)

# %%
# convert [False, True, False] to ['No', 'Yes', 'No']
bool_to_str = lambda items: ["No" if item == False else "Yes" for item in items]
bool_to_str([False, True, True])
# Out:
# ['No', 'Yes', 'Yes']

# %%
# Default
pipe.fit(X=X_train_val, y=y_train_val)
y_pred_proba = pipe.predict_proba(X_test)
print(classification_report(y_true=y_test, y_pred=bool_to_str(y_pred_proba[:,1] >= 0.3)))
# Out:
# Metal device set to: Apple M1
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
#
#               precision    recall  f1-score   support
#
#           No       0.91      0.78      0.84       777
#          Yes       0.56      0.78      0.65       280
#
#     accuracy                           0.78      1057
#    macro avg       0.73      0.78      0.74      1057
# weighted avg       0.82      0.78      0.79      1057

# %%
params = {
    "clf__hidden_layer_dim": [8],
    "clf__loss": ["binary_crossentropy"],
    "clf__optimizer": ["sgd", "adam"],
    "clf__metrics__threshold": [0.3]
}
gs = GridSearchCV(
    pipe, params, refit=False, cv=3, 
    scoring=make_scorer(
        score_func=f1_score,
        average='macro',
        labels=['Yes']
    ),
    n_jobs=-1
)

gs.fit(X_train_val, y_train_val)
# Out:
# INFO:tensorflow:Assets written to: ram:///var/folders/w9/5lrd8m1x4f586v9ynn8xrryw0000gn/T/tmp0om8t0bd/assets
# INFO:tensorflow:Assets written to: ram:///var/folders/w9/5lrd8m1x4f586v9ynn8xrryw0000gn/T/tmpnx8u2kxj/assets
# INFO:tensorflow:Assets written to: ram:///var/folders/w9/5lrd8m1x4f586v9ynn8xrryw0000gn/T/tmp2ed2rl9p/assets
# INFO:tensorflow:Assets written to: ram:///var/folders/w9/5lrd8m1x4f586v9ynn8xrryw0000gn/T/tmp2q95tozi/assets
# INFO:tensorflow:Assets written to: ram:///var/folders/w9/5lrd8m1x4f586v9ynn8xrryw0000gn/T/tmpd166qekn/assets
# INFO:tensorflow:Assets written to: ram:///var/folders/w9/5lrd8m1x4f586v9ynn8xrryw0000gn/T/tmpx0yzlyw8/assets
# INFO:tensorflow:Assets written to: ram:///var/folders/w9/5lrd8m1x4f586v9ynn8xrryw0000gn/T/tmp5p14p5wr/assets
# INFO:tensorflow:Assets written to: ram:///var/folders/w9/5lrd8m1x4f586v9ynn8xrryw0000gn/T/tmpgv7u3e89/assets
# INFO:tensorflow:Assets written to: ram:///var/folders/w9/5lrd8m1x4f586v9ynn8xrryw0000gn/T/tmpp9xnqie3/assets
# INFO:tensorflow:Assets written to: ram:///var/folders/w9/5lrd8m1x4f586v9ynn8xrryw0000gn/T/tmp0wz46tf0/assets
# INFO:tensorflow:Assets written to: ram:///var/folders/w9/5lrd8m1x4f586v9ynn8xrryw0000gn/T/tmpc7nwf_e8/assets
# Metal device set to: Apple M1
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
#
# INFO:tensorflow:Assets written to: ram:///var/folders/w9/5lrd8m1x4f586v9ynn8xrryw0000gn/T/tmpr__58t67/assets
# Metal device set to: Apple M1
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
#
# INFO:tensorflow:Assets written to: ram:///var/folders/w9/5lrd8m1x4f586v9ynn8xrryw0000gn/T/tmppgifzmp1/assets
# Metal device set to: Apple M1
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
#
# Metal device set to: Apple M1
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
#
# Metal device set to: Apple M1
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
#
# Metal device set to: Apple M1
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('composer',
#                                         ColumnTransformer(transformers=[('num_pipe',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(strategy='median')),
#                                                                                          ('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['tenure',
#                                                                           'MonthlyCharges',
#                                                                           'TotalCharges']),
#                                                                         ('nom_pipe',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('encoder',
#                                                                                           OneHotEncoder(categories...
#                                         KerasClassifier(callbacks=[<keras.callbacks.EarlyStopping object at 0x17b93bf10>], epochs=100, hidden_layer_dim=100, loss='binary_crossentropy', metrics=<class 'tensorflow_addons.metrics.f_scores.F1Score'>, metrics__average='macro', metrics__num_classes=1, metrics__threshold=0.3, model=<function get_model at 0x17b8f3910>, validation_split=0.1, verbose=False))]),
#              n_jobs=-1,
#              param_grid={'clf__hidden_layer_dim': [8],
#                          'clf__loss': ['binary_crossentropy'],
#                          'clf__metrics__threshold': [0.3],
#                          'clf__optimizer': ['sgd', 'adam']},
#              refit=False,
#              scoring=make_scorer(f1_score, average=macro, labels=['Yes']))

# %%
# Get best params
print(gs.best_score_, gs.best_params_)
# Out:
# 0.55886498148867 {'clf__hidden_layer_dim': 8, 'clf__loss': 'binary_crossentropy', 'clf__metrics__threshold': 0.3, 'clf__optimizer': 'adam'}
